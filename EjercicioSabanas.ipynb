# %%
import json

with open('SABANAS-INE_ELECCION_2012/file_id-0.json', 'r') as file:
    data = json.load(file)
data
# Out:
# {'sabanas': [{'id': '4',
#    'proyecto': 'YoSoyAntiFraude',
#    'fuente': 'twitter.com',
#    'imagen': 'http://cdnsabanas.yosoyantifraude.org/7cc44124432c2c06921504f125b8b86666171f4a-original.jpg',
#    'imagen_original': 'http://sabanasraw.yosoyantifraude.org/7cc44124432c2c06921504f125b8b86666171f4a',
#    'entidad': '24',
#    'municipio': 'San Luis Potosi',
#    'distrito': '6',
#    'seccion': '989',
#    'tipoCasilla': 'C1',
#    'sha': '7cc44124432c2c06921504f125b8b86666171f4a',
#    'idcasilla': '32818',
#    'revision': '2',
#    'resultados': {'pan': '100',
#     'pri': '47',
#     'prd': '63',
#     'verde': '3',
#     'pt': '6',
#     'mov': '8',
#     'nuevaAlianza': '7',
#     'pri_verde': '19',
#     'prd_pt_mov': '24',
#     'prd_pt': '1',
#     'prd_mov': '1',
#     'pt_mov': '0',
#     'noRegistrados': '0',
#     'nulos': '6'}},
#   {'id': '5',
#    'proyecto': 'YoSoyAntiFraude',
#    'fuente': 'twitter.com',
# ...

# %% [markdown]
# ## Conteo de votos

# %%
import json

with open('SABANAS-INE_ELECCION_2012/file_id-0.json', 'r') as file:
    data = json.load(file)
data
CountVerde = 0
for sabana in data['sabanas']:
    #print('id', sabana['id'])
    if(sabana["municipio"] == "Merida"):
        CountVerde += int(sabana["resultados"]["pri"])
CountVerde
# Out:
# 502
